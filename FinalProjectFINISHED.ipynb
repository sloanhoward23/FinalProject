# %% [markdown]
# # Final Project
#
#
# My final project is going to be using stats from the website basketball-reference.com.
# My question is Which NBA player has been the best over the last 5 seasons (not including the current 2020-2021 season).
# I obtained the Per Game Stats for every player in the NBA from the last five seasons and also the Advanced Statistics as well. Below I will be loading in all 10 files and showing the .head information. I will not be using all of the advanced stats as only a couple of the statistics really matter. I'm paticularly going to look that the player efficiecy rating (PER), as it shows how efficient a player really was on the court.
#
# My analysis goal is to be able to create a top 10 list of players because there were so many great seasons over the last 5 years that it needs to be cut down to a final 10. I will begin to search for players that I know had a great season off the top of my head. Those players will take up the first 5 players of the list. The next five players will be sleeper players that I've looked throughout the files for that have also had amazing seasons that deserve to be on the list.
#
#
# To complete my analysis plan, I will have a list consisting of 10 players with great seasons and have the list narrowed down to a top 5. Once I graph and analyze the top 5 players per game, PER, and team season performances, I will be able to make a decision on my question.

# %%
import pandas as pd
import numpy as np

# %%
per_game1 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\15-16.csv')

# %%
per_game1.keys()
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
per_game1_top = per_game1.head()
per_game1_top
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1       Quincy Acy\acyqu01  PF   25  SAC  59  29  14.8  2.0   3.6  ...
# 1   2   Jordan Adams\adamsjo01  SG   21  MEM   2   0   7.5  1.0   3.0  ...
# 2   3   Steven Adams\adamsst01   C   22  OKC  80  80  25.2  3.3   5.3  ...
# 3   4  Arron Afflalo\afflaar01  SG   30  NYK  71  57  33.4  5.0  11.3  ...
# 4   5  Alexis Ajinça\ajincal01   C   27  NOP  59  17  14.6  2.5   5.3  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.735  1.1  2.1  3.2  0.5  0.5  0.4  0.5  1.7   5.2
# 1  0.600  0.0  1.0  1.0  1.5  1.5  0.0  1.0  1.0   3.5
# 2  0.582  2.7  3.9  6.7  0.8  0.5  1.1  1.1  2.8   8.0
# 3  0.840  0.3  3.4  3.7  2.0  0.4  0.1  1.2  2.0  12.8
# 4  0.839  1.3  3.3  4.6  0.5  0.3  0.6  0.9  2.3   6.0
#
# [5 rows x 30 columns]

# %%
per_game2 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\16-17.csv')

# %%
per_game2.keys()
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
per_game2_top = per_game2.head()
per_game2_top
# Out:
#    Rk                  Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1  Álex Abrines\abrinal01  SG   23  OKC  68   6  15.5  2.0  5.0  ...
# 1   2      Quincy Acy\acyqu01  PF   26  TOT  38   1  14.7  1.8  4.5  ...
# 2   2      Quincy Acy\acyqu01  PF   26  DAL   6   0   8.0  0.8  2.8  ...
# 3   2      Quincy Acy\acyqu01  PF   26  BRK  32   1  15.9  2.0  4.8  ...
# 4   3  Steven Adams\adamsst01   C   23  OKC  80  80  29.9  4.7  8.2  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.898  0.3  1.0  1.3  0.6  0.5  0.1  0.5  1.7   6.0
# 1  0.750  0.5  2.5  3.0  0.5  0.4  0.4  0.6  1.8   5.8
# 2  0.667  0.3  1.0  1.3  0.0  0.0  0.0  0.3  1.5   2.2
# 3  0.754  0.6  2.8  3.3  0.6  0.4  0.5  0.6  1.8   6.5
# 4  0.611  3.5  4.2  7.7  1.1  1.1  1.0  1.8  2.4  11.3
#
# [5 rows x 30 columns]

# %%
per_game3 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\17-18.csv')

# %%
per_game3_top = per_game3.head()
per_game3_top
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1   Álex Abrines\abrinal01  SG   24  OKC  75   8  15.1  1.5  3.9  ...
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70   8  19.4  1.9  5.2  ...
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  76  32.7  5.9  9.4  ...
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  19  19.8  2.5  4.9  ...
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   3  12.9  1.2  3.1  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.848  0.3  1.2  1.5  0.4  0.5  0.1  0.3  1.7   4.7
# 1  0.817  0.6  3.1  3.7  0.8  0.5  0.4  0.9  2.1   5.9
# 2  0.559  5.1  4.0  9.0  1.2  1.2  1.0  1.7  2.8  13.9
# 3  0.721  1.7  3.8  5.5  1.5  0.5  0.6  1.0  2.0   6.9
# 4  0.846  0.1  1.2  1.2  0.6  0.1  0.2  0.4  1.1   3.4
#
# [5 rows x 30 columns]

# %%
per_game4 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\18-19.csv')

# %%
per_game4_top = per_game4.head()
per_game4_top
# Out:
#    Rk                  Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1  Álex Abrines\abrinal01  SG   25  OKC  31   2  19.0  1.8   5.1  ...
# 1   2      Quincy Acy\acyqu01  PF   28  PHO  10   0  12.3  0.4   1.8  ...
# 2   3  Jaylen Adams\adamsja01  PG   22  ATL  34   1  12.6  1.1   3.2  ...
# 3   4  Steven Adams\adamsst01   C   25  OKC  80  80  33.4  6.0  10.1  ...
# 4   5   Bam Adebayo\adebaba01   C   21  MIA  82  28  23.3  3.4   5.9  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.923  0.2  1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  0.700  0.3  2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  0.778  0.3  1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  0.500  4.9  4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  0.735  2.0  5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
per_game5 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\19-20.csv')

# %%
per_game5_top = per_game5.head()
per_game5_top
# Out:
#    Rk                              Player Pos  Age   Tm   G  GS    MP   FG  \
# 0   1              Steven Adams\adamsst01   C   26  OKC  63  63  26.7  4.5
# 1   2               Bam Adebayo\adebaba01  PF   22  MIA  72  72  33.6  6.1
# 2   3         LaMarcus Aldridge\aldrila01   C   34  SAS  53  53  33.1  7.4
# 3   4            Kyle Alexander\alexaky01   C   23  MIA   2   0   6.5  0.5
# 4   5  Nickeil Alexander-Walker\alexani01  SG   21  NOP  47   1  12.6  2.1
#
#     FGA  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.6  ...  0.582  3.3  6.0   9.3  2.3  0.8  1.1  1.5  1.9  10.9
# 1  11.0  ...  0.691  2.4  7.8  10.2  5.1  1.1  1.3  2.8  2.5  15.9
# 2  15.0  ...  0.827  1.9  5.5   7.4  2.4  0.7  1.6  1.4  2.4  18.9
# 3   1.0  ...    NaN  1.0  0.5   1.5  0.0  0.0  0.0  0.5  0.5   1.0
# 4   5.7  ...  0.676  0.2  1.6   1.8  1.9  0.4  0.2  1.1  1.2   5.7
#
# [5 rows x 30 columns]

# %%
advanced1 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\15-16Advanced.csv')

# %%
advanced1_top = advanced1.head()
advanced1_top
# Out:
#    Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1       Quincy Acy\acyqu01  PF   25  SAC  59   876  14.7  0.629  0.229
# 1   2   Jordan Adams\adamsjo01  SG   21  MEM   2    15  17.3  0.427  0.167
# 2   3   Steven Adams\adamsst01   C   22  OKC  80  2014  15.5  0.621  0.000
# 3   4  Arron Afflalo\afflaar01  SG   30  NYK  71  2371  10.9  0.531  0.298
# 4   5  Alexis Ajinça\ajincal01   C   27  NOP  59   861  13.8  0.514  0.003
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  ...          NaN  1.8  0.7  2.5  0.137          NaN  -0.2   0.2 -0.1   0.4
# 1  ...          NaN  0.0  0.0  0.0  0.015          NaN  -2.5   9.4  6.9   0.0
# 2  ...          NaN  4.2  2.3  6.5  0.155          NaN   0.0   0.2  0.2   1.1
# 3  ...          NaN  1.8  0.9  2.7  0.055          NaN  -1.3  -1.6 -2.9  -0.5
# 4  ...          NaN  0.2  0.9  1.0  0.058          NaN  -3.4  -0.6 -4.0  -0.4
#
# [5 rows x 29 columns]

# %%
advanced2 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\16-17Advanced.csv')

# %%
advanced2_top = advanced2.head()
advanced2_top
# Out:
#    Rk                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1  Álex Abrines\abrinal01  SG   23  OKC  68  1055  10.1  0.560  0.724
# 1   2      Quincy Acy\acyqu01  PF   26  TOT  38   558  11.8  0.565  0.529
# 2   2      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4  0.355  0.412
# 3   2      Quincy Acy\acyqu01  PF   26  BRK  32   510  13.1  0.587  0.542
# 4   3  Steven Adams\adamsst01   C   23  OKC  80  2389  16.5  0.589  0.002
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM   BPM  VORP
# 0  ...          NaN  1.2  0.9  2.1  0.096          NaN  -1.3  -0.4  -1.6   0.1
# 1  ...          NaN  0.5  0.5  0.9  0.082          NaN  -1.5  -0.6  -2.1   0.0
# 2  ...          NaN -0.2  0.0 -0.1 -0.133          NaN -10.3  -4.1 -14.3  -0.1
# 3  ...          NaN  0.6  0.5  1.1  0.102          NaN  -0.6  -0.2  -0.9   0.1
# 4  ...          NaN  3.3  3.1  6.5  0.130          NaN  -0.2   0.0  -0.2   1.1
#
# [5 rows x 29 columns]

# %%
advanced3 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\17-18Advanced.csv')

# %%
advanced3_top = advanced3.head()
advanced3_top
# Out:
#    Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1   Álex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  2487  20.6  0.630  0.003
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7  0.570  0.021
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8  0.516  0.432
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  ...          NaN  1.3  1.0  2.2  0.094          NaN  -1.9   0.4 -1.5   0.1
# 1  ...          NaN -0.1  1.1  1.0  0.036          NaN  -2.6   0.1 -2.5  -0.2
# 2  ...          NaN  6.7  3.0  9.7  0.187          NaN   1.7  -0.6  1.1   2.0
# 3  ...          NaN  2.3  1.9  4.2  0.148          NaN  -1.1   0.7 -0.4   0.6
# 4  ...          NaN -0.1  0.2  0.1  0.009          NaN  -3.8  -1.5 -5.4  -0.6
#
# [5 rows x 29 columns]

# %%
advanced4 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\18-19Advanced.csv')

# %%
advanced4_top = advanced4.head()
advanced4_top
# Out:
#    Rk                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1  Álex Abrines\abrinal01  SG   25  OKC  31   588   6.3  0.507  0.809
# 1   2      Quincy Acy\acyqu01  PF   28  PHO  10   123   2.9  0.379  0.833
# 2   3  Jaylen Adams\adamsja01  PG   22  ATL  34   428   7.6  0.474  0.673
# 3   4  Steven Adams\adamsst01   C   25  OKC  80  2669  18.5  0.591  0.002
# 4   5   Bam Adebayo\adebaba01   C   21  MIA  82  1913  17.9  0.623  0.031
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  ...          NaN  0.1  0.6  0.6  0.053          NaN  -3.7   0.4 -3.3  -0.2
# 1  ...          NaN -0.1  0.0 -0.1 -0.022          NaN  -7.6  -0.5 -8.1  -0.2
# 2  ...          NaN -0.1  0.2  0.1  0.011          NaN  -3.8  -0.5 -4.3  -0.2
# 3  ...          NaN  5.1  4.0  9.1  0.163          NaN   0.7   0.4  1.1   2.1
# 4  ...          NaN  3.4  3.4  6.8  0.171          NaN  -0.4   2.2  1.8   1.8
#
# [5 rows x 29 columns]

# %%
advanced5 = pd.read_csv(r'C:\Users\ADMIN\Desktop\Senior Year 2.0\DataInEmat\19-20Advanced.csv')

# %%
advanced5_top = advanced5.head()
advanced5_top
# Out:
#    Rk                              Player Pos  Age   Tm   G    MP   PER  \
# 0   1              Steven Adams\adamsst01   C   26  OKC  63  1680  20.5
# 1   2               Bam Adebayo\adebaba01  PF   22  MIA  72  2417  20.3
# 2   3         LaMarcus Aldridge\aldrila01   C   34  SAS  53  1754  19.7
# 3   4            Kyle Alexander\alexaky01   C   23  MIA   2    13   4.7
# 4   5  Nickeil Alexander-Walker\alexani01  SG   21  NOP  47   591   8.9
#
#      TS%   3PAr  ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  \
# 0  0.604  0.006  ...          NaN  3.8  2.7  6.5  0.185          NaN   1.9
# 1  0.598  0.018  ...          NaN  4.6  3.9  8.5  0.168          NaN   1.4
# 2  0.571  0.198  ...          NaN  3.0  1.4  4.5  0.122          NaN   1.8
# 3  0.500  0.000  ...          NaN  0.0  0.0  0.0 -0.003          NaN  -6.1
# 4  0.473  0.500  ...          NaN -0.7  0.4 -0.2 -0.020          NaN  -3.2
#
#    DBPM  BPM  VORP
# 0   1.1  2.9   2.1
# 1   2.0  3.4   3.3
# 2  -0.5  1.4   1.5
# ...

# %%
per_game1_df = pd.DataFrame(per_game1)
print(per_game1_df.iloc[116])
# Out:
# Rk                            105
# Player    Stephen Curry\curryst01
# Pos                            PG
# Age                            27
# Tm                            GSW
# G                              79
# GS                             79
# MP                           34.2
# FG                           10.2
# FGA                          20.2
# FG%                         0.504
# 3P                            5.1
# 3PA                          11.2
# 3P%                         0.454
# 2P                            5.1
# 2PA                           9.0
# 2P%                         0.566
# eFG%                         0.63
# FT                            4.6
# FTA                           5.1
# FT%                         0.908
# ORB                           0.9
# DRB                           4.6
# TRB                           5.4
# AST                           6.7
# STL                           2.1
# BLK                           0.2
# ...

# %%
per_game3_df = pd.DataFrame(per_game3)
print(per_game3_df.iloc[303])
# Out:
# Rk                           248
# Player    LeBron James\jamesle01
# Pos                           PF
# Age                           33
# Tm                           CLE
# G                             82
# GS                            82
# MP                          36.9
# FG                          10.5
# FGA                         19.3
# FG%                        0.542
# 3P                           1.8
# 3PA                          5.0
# 3P%                        0.367
# 2P                           8.6
# 2PA                         14.3
# 2P%                        0.603
# eFG%                        0.59
# FT                           4.7
# FTA                          6.5
# FT%                        0.731
# ORB                          1.2
# DRB                          7.5
# TRB                          8.6
# AST                          9.1
# STL                          1.4
# BLK                          0.9
# TOV                          4.2
# ...

# %%
per_game5_df = pd.DataFrame(per_game5)
print(per_game5_df.iloc[12])
# Out:
# Rk                                     13
# Player    Giannis Antetokounmpo\antetgi01
# Pos                                    PF
# Age                                    25
# Tm                                    MIL
# G                                      63
# GS                                     63
# MP                                   30.4
# FG                                   10.9
# FGA                                  19.7
# FG%                                 0.553
# 3P                                    1.4
# 3PA                                   4.7
# 3P%                                 0.304
# 2P                                    9.5
# 2PA                                  15.0
# 2P%                                 0.631
# eFG%                                0.589
# FT                                    6.3
# FTA                                  10.0
# FT%                                 0.633
# ORB                                   2.2
# ...

# %%
per_game4_df = pd.DataFrame(per_game4)
print(per_game4_df.iloc[267])
# Out:
# Rk                           206
# Player    James Harden\hardeja01
# Pos                           PG
# Age                           29
# Tm                           HOU
# G                             78
# GS                            78
# MP                          36.8
# FG                          10.8
# FGA                         24.5
# FG%                        0.442
# 3P                           4.8
# 3PA                         13.2
# 3P%                        0.368
# 2P                           6.0
# 2PA                         11.3
# 2P%                        0.528
# eFG%                       0.541
# FT                           9.7
# FTA                         11.0
# FT%                        0.879
# ORB                          0.8
# DRB                          5.8
# TRB                          6.6
# AST                          7.5
# STL                          2.0
# BLK                          0.7
# TOV                          5.0
# ...

# %%
per_game2_df = pd.DataFrame(per_game2)
print(per_game2_df.iloc[558])
# Out:
# Rk                                458
# Player    Russell Westbrook\westbru01
# Pos                                PG
# Age                                28
# Tm                                OKC
# G                                  81
# GS                                 81
# MP                               34.6
# FG                               10.2
# FGA                              24.0
# FG%                             0.425
# 3P                                2.5
# 3PA                               7.2
# 3P%                             0.343
# 2P                                7.7
# 2PA                              16.8
# 2P%                             0.459
# eFG%                            0.476
# FT                                8.8
# FTA                              10.4
# FT%                             0.845
# ORB                               1.7
# DRB                               9.0
# TRB                              10.7
# AST                              10.4
# ...

# %%
per_game1_df = pd.DataFrame(per_game1)
print(per_game1_df.iloc[421])
# Out:
# Rk                        348
# Player    Chris Paul\paulch01
# Pos                        PG
# Age                        30
# Tm                        LAC
# G                          74
# GS                         74
# MP                       32.7
# FG                        7.0
# FGA                      15.1
# FG%                     0.462
# 3P                        1.6
# 3PA                       4.4
# 3P%                     0.371
# 2P                        5.3
# 2PA                      10.6
# 2P%                     0.501
# eFG%                    0.517
# FT                        4.0
# FTA                       4.4
# FT%                     0.896
# ORB                       0.5
# DRB                       3.7
# TRB                       4.2
# AST                      10.0
# STL                       2.1
# BLK                       0.2
# TOV                       2.6
# PF                        2.5
# PTS                      19.5
# Name: 421, dtype: object

# %%
per_game2_df = pd.DataFrame(per_game2)
print(per_game2_df.iloc[122])
# Out:
# Rk                            100
# Player    Anthony Davis\davisan02
# Pos                             C
# Age                            23
# Tm                            NOP
# G                              75
# GS                             75
# MP                           36.1
# FG                           10.3
# FGA                          20.3
# FG%                         0.505
# 3P                            0.5
# 3PA                           1.8
# 3P%                         0.299
# 2P                            9.7
# 2PA                          18.6
# 2P%                         0.524
# eFG%                        0.518
# FT                            6.9
# FTA                           8.6
# FT%                         0.802
# ORB                           2.3
# DRB                           9.5
# TRB                          11.8
# AST                           2.1
# STL                           1.3
# BLK                           2.2
# ...

# %%
per_game1_df = pd.DataFrame(per_game1)
print(per_game1_df.iloc[264])
# Out:
# Rk                           221
# Player    LeBron James\jamesle01
# Pos                           SF
# Age                           31
# Tm                           CLE
# G                             76
# GS                            76
# MP                          35.6
# FG                           9.7
# FGA                         18.6
# FG%                         0.52
# 3P                           1.1
# 3PA                          3.7
# 3P%                        0.309
# 2P                           8.6
# 2PA                         14.9
# 2P%                        0.573
# eFG%                       0.551
# FT                           4.7
# FTA                          6.5
# FT%                        0.731
# ORB                          1.5
# DRB                          6.0
# TRB                          7.4
# AST                          6.8
# STL                          1.4
# BLK                          0.6
# TOV                          3.3
# ...

# %%
per_game5_df = pd.DataFrame(per_game5)
print(per_game5_df.iloc[177])
# Out:
# Rk                          134
# Player    Luka Dončić\doncilu01
# Pos                          PG
# Age                          20
# Tm                          DAL
# G                            61
# GS                           61
# MP                         33.6
# FG                          9.5
# FGA                        20.6
# FG%                       0.463
# 3P                          2.8
# 3PA                         8.9
# 3P%                       0.316
# 2P                          6.7
# 2PA                        11.7
# 2P%                       0.574
# eFG%                      0.531
# FT                          7.0
# FTA                         9.2
# FT%                       0.758
# ORB                         1.3
# DRB                         8.1
# TRB                         9.4
# AST                         8.8
# STL                         1.0
# BLK                         0.2
# TOV                         4.3
# PF                          2.5
# ...

# %%
per_game3_df = pd.DataFrame(per_game3)
print(per_game3_df.iloc[232])
# Out:
# Rk                           194
# Player    James Harden\hardeja01
# Pos                           SG
# Age                           28
# Tm                           HOU
# G                             72
# GS                            72
# MP                          35.4
# FG                           9.0
# FGA                         20.1
# FG%                        0.449
# 3P                           3.7
# 3PA                         10.0
# 3P%                        0.367
# 2P                           5.4
# 2PA                         10.1
# 2P%                        0.531
# eFG%                       0.541
# FT                           8.7
# FTA                         10.1
# FT%                        0.858
# ORB                          0.6
# DRB                          4.8
# TRB                          5.4
# AST                          8.8
# STL                          1.8
# BLK                          0.7
# TOV                          4.4
# ...

# %% [markdown]
# Top 10 list:
# 1. 2015-16 Steph Curry
# 2. 2017-18 LeBron James
# 3. 2019-20 Giannis Antetokoumpo
# 4. 2018-19 James Harden
# 5. 2016-17 Russell Westbrook
# 6. 2015-16 Chris Paul
# 7. 2016-17 Anthony Davis
# 8. 2015-16 LeBron James
# 9. 2019-20 Luka Doncic
# 10. 2017-18 James Harden
# Next, I will be narrowing down the list by team success to 5 as it will show the players value and graphing the player stats.

# %% [markdown]
# Number 1 on the top 5 list is 2015-16 season Stephen Curry. He was the first ever unanimous league MVP with the stats of 30,5,6 a game and breaking his own NBA record of three pointers made in a season! His team won a record 73 games and went to the NBA finals. The warriors eventually lost to number 2 on this list.

# %% [markdown]
# Number 2 is LeBron James from the 2015-16 season. He averaged 25,7,7, and led his team to one of the most memorable playoff runs in NBA history. His team won the NBA Finals by beating the Warriors coming back down 3-1 and beating the unianimous MVP Steph Curry.

# %% [markdown]
# Number 3 is LeBron James from the 2018-19 season. After his All-star teammate Kyrie Irving left the team, the Cavaliers were in shambles. They built a makeshift team around LeBron and even through all the random trades and turmoil this man still went to the NBA finals!! Avergaing the numbers 28,9,9 at age 33 is also a huge accomplishment. His highlights from this playoff run are amazing.

# %% [markdown]
# Number 4 is James Harden's 2017-2018 season. This season James Harden won the NBA MVP and led his team to one game away from the NBA Finals. His team was plagued with injuries all season including his star teammate Chris Paul. Harden led the way with a very efficient season averaging 30,5,9 and did much of the same in the playoffs. His team lost 3-4 to the eventual NBA champion Golden State Warriors.

# %% [markdown]
# Finally, Number 5 is Luka Doncic from the 2019-20 season. Although his team did not make it far in the playoffs (2-4 series loss to the Los Angeles Clippers), Luka put up one of the greatest stat lines for a player under 22 years old in NBA history. Averaging 29, 9, 9, he carried his lackluster Mavericks team to a playoff apperance and put up a good fight against a championship caliber team in the Clippers.
#
# Below I will be graphing each players stats and compare them too each other. After comparing stats I will come up with an answer to my question for this project.

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Below I tried graphing all their per game stats together so I could get a good comparative look at their stats, but this was the error code that constantly would pop up when I tried to do so. Combining their data seemed to be an issue and the only way I could compare their stats was to create a seperate bar graph for each players stats. Below, I will be plotting bar graphs for the top 5 players per game and player efficiency rating (PER) stats, so I can make a decision on my question.

# %%
Steph = per_game1_df.loc[per_game1['Player'] == "Stephen Curry\curryst01"]
LeBron1 = per_game1_df.loc[per_game1['Player'] == "LeBron James\jamesle01"]
LeBron2 = per_game3_df.loc[per_game3['Player'] == "LeBron James\jamesle01"]
Harden = per_game3_df.loc[per_game3['Player'] == "James Harden\hardeja01"]
Luka = per_game5_df.loc[per_game5['Player'] == "Luka Dončić\doncilu01"]
index = ['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
       '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
       'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
top5_df = pd.DataFrame({'Steph': Steph, 'LeBron1': LeBron1, 'LeBron2': LeBron2, 'Harden': Harden, 'Luka': Luka}, index=index)
top5Bar= top5_df.plot.bar(rot=0, subplots=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-c6b98919ca32> in <module>
#       8        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
#       9 top5_df = pd.DataFrame({'Steph': Steph, 'LeBron1': LeBron1, 'LeBron2': LeBron2, 'Harden': Harden, 'Giannis': Giannis}, index=index)
# ---> 10 top5Bar= top5_df.plot.bar(rot=0, subplots=True)
#
# ~\anaconda3\envs\datainemat\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1111         other axis represents a measured value.
#    1112         """
# -> 1113         return self(kind="bar", x=x, y=y, **kwargs)
#    1114
#    1115     @Appender(
#
# ~\anaconda3\envs\datainemat\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# ...

# %%
Steph = per_game1_df.loc[per_game1['Player'] == "Stephen Curry\curryst01"]
stephBar = Steph.plot.bar(x = 'Player', rot=0)

# %%
LeBron1 = per_game1_df.loc[per_game1['Player'] == "LeBron James\jamesle01"]
lebronBar= LeBron1.plot.bar(x = 'Player', rot=0)

# %%
LeBron2 = per_game3_df.loc[per_game3['Player'] == "LeBron James\jamesle01"]
lebron2Bar = LeBron2.plot.bar(x = 'Player', rot=0)

# %%
Harden = per_game3_df.loc[per_game3['Player'] == "James Harden\hardeja01"]
hardenBar = Harden.plot.bar(x = 'Player', rot=0)

# %%
Luka = per_game5_df.loc[per_game5['Player'] == "Luka Dončić\doncilu01"]
LukaBar = Luka.plot.bar(x = 'Player', rot=0)

# %%
StephAdvanced = advanced1.loc[advanced1['Player'] == "Stephen Curry\curryst01"]
stephadvancedBar = StephAdvanced.plot.bar(x = 'Player', y = 'PER', rot=0)

# %%
LeBron1Advanced = advanced1.loc[advanced1['Player'] == "LeBron James\jamesle01"]
lebron1advancedbar = LeBron1Advanced.plot.bar(x = "Player", y = 'PER', rot=0)

# %%
LeBron2Advanced = advanced3.loc[advanced3['Player'] == "LeBron James\jamesle01"]
lebron2advancedbar = LeBron2Advanced.plot.bar(x = 'Player', y = 'PER', rot=0)

# %%
HardenAdvanced = advanced3.loc[advanced3['Player'] == "James Harden\hardeja01"]
hardenAdvancedBar = HardenAdvanced.plot.bar(x = 'Player', y = 'PER', rot=0)

# %%
LukaAdvanced = advanced5.loc[advanced5['Player'] == "Luka Dončić\doncilu01"]
lukaadvancedBar = LukaAdvanced.plot.bar(x = 'Player', y = 'PER', rot=0)

# %% [markdown]
# After thorughouly viewing my analysis plan and doing some more research on each players team success, I have come up with an answer. Analyzing the per game stats, player efficency rating, and team success, I believe that 2015-2016 season Stephen Curry has had the best season over the last 5 years in the NBA. Curry had the best player efficiency rating of the players in this list and is in the top ten all time! His team has the 2nd best success winning the Western Conference Champoionship and falling one game short of winning an NBA championship losing to a player who was a close second in my decison, 15-16 LeBron James. He won the NBA MVP unanimously for the first time in NBA History and his team only lost 9 games out of a 82 game season! 73 wins in an NBA season remains as the NBA record and will likely hold for a while. His statistics were off the chart as well. He was the only player to average over 30 points per game this season at 30.1, also averaged 5 rebounds (which is high for a 6'3 point guard), and almost 7 assists a game which means he was keeping his teammates invloved as well. His effective shooting percentage was a whopping 63%, which is one of the most effecient in NBA history. With the amount of accolades he acheived and records he broke, I feel like this was the best season over the last 5 years and I do not see any one topping this season for the next 20!
#
# In conclusion, I had fun doing this project because it dealt with something that I was very interested in and had an answer that I was very curious to find out. I was able to use multiple features in python that I learned from this course and I had fun applying what I've learned to do something I was interested in. This was my first time doing my own NBA statistical analysis and I was very excited to jump on this project as soon as possible. I definetly would like to do some more of this in my free time and be able to answer more sports questions with data analysis. I would love to do something like this as a job one day and be able to report my analysis online in articles/blogs or even on TV.
